# %% [markdown]
# # 🌐 Artificial Neural Network (ANN) এর জ্যামিতিক (Geometric) দৃষ্টিভঙ্গি
#
# ## 🎯 মূল ধারণা:
#
# Artificial Neural Network-এর প্রতিটি লেয়ার একটি **জ্যামিতিক রূপান্তর (geometric transformation)** হিসেবে কাজ করে। এটি মূলত ইনপুট স্পেসকে ধাপে ধাপে এমনভাবে রূপান্তর করে, যাতে তা আউটপুট স্পেসে স্পষ্টভাবে বিভাজনযোগ্য (separable) হয়ে উঠে।
#
# ---
#
# ## 🧠 একটি নিউরনের জ্যামিতিক ব্যাখ্যা:
#
# - প্রতিটি নিউরন একটি **হাইপারপ্লেন (hyperplane)** তৈরি করে যা ইনপুট স্পেসকে দুইটি ভাগে বিভক্ত করে।
# - এই হাইপারপ্লেনটি নির্ধারিত হয়:
#   \[
#   w_1x_1 + w_2x_2 + \dots + w_nx_n + b = 0
#   \]
# - এটি একটি decision boundary তৈরি করে। এক পাশে positive class, অন্য পাশে negative class।
#
# ---
#
# ## 🔁 Hidden Layer এর ভূমিকা:
#
# - Hidden layer গুলো ইনপুট স্পেসকে **non-linear space** এ রূপান্তর করে।
# - প্রতিটি লেয়ার ইনপুট ডেটাকে twist, rotate, stretch করে যাতে output layer সহজে decision নিতে পারে।
#
# ---
#
# ## 📊 উদাহরণ:
#
# ধরি, আমাদের কাছে দুইটি class আছে যেগুলো একটি বৃত্তের দুই পাশে অবস্থান করছে — অর্থাৎ, তারা **linearly separable নয়**।
#
# - প্রথম লেয়ার ইনপুট স্পেসকে নতুনভাবে ম্যাপ করে যেন এই বৃত্তের মতো স্ট্রাকচার ফ্ল্যাট বা লিনিয়ার হয়ে যায়।
# - এরপর fully connected layers এবং non-linear activation functions মিলে এই space কে এমনভাবে পরিবর্তন করে যাতে class গুলো **linear decision boundary** দিয়ে ভাগ করা যায়।
#
# ---
#
# ## 🌀 Activation Function এর ভূমিকা (Geometrically):
#
# - Activation function (যেমন: ReLU, Sigmoid) ডেটার জ্যামিতিক রূপে non-linearity যোগ করে।
# - এটা ডেটাকে এমনভাবে warp করে যাতে হাইপারপ্লেন decision boundary তৈরি করা যায়।
#
# ---
#
# ## 🧩 সহজ ভাষায়:
#
# - **প্রতিটি লেয়ার** ডেটার জ্যামিতিক অবস্থা পরিবর্তন করে (space transformation)।
# - **শুরুর দিকে**, ডেটা লিনিয়ারভাবে আলাদা না হলেও,
# - **শেষের দিকে**, ডেটা এমনভাবে ম্যাপ হয় যাতে একটি simple লাইন বা plane দিয়েই decision নেওয়া যায়।
#
# ---
#
# ## 📌 চূড়ান্তভাবে মনে রাখার মতো:
#
# | অংশ | জ্যামিতিক ব্যাখ্যা |
# |-----|---------------------|
# | নিউরন | একটি হাইপারপ্লেন তৈরি করে |
# | লেয়ার | ইনপুট স্পেসকে নতুন স্পেসে রূপান্তর করে |
# | অ্যাক্টিভেশন | নন-লিনিয়ার ডিস্টরশন দেয় |
# | ট্রেনিং | এই ট্রান্সফর্মেশনকে অপটিমাইজ করে যাতে decision boundary তৈরি হয় |
