# %% [markdown]
# <h2>🔍 What Are <i>Metaparameters</i>?</h2>
#
# <p><b>Metaparameters</b> (also known as <b>hyperparameters</b>) are settings that control the training process of a machine learning model but are <u>not learned from the data</u>. They are set <b>before</b> training starts.</p>
#
# <hr>
#
# <h3>📘 Definition:</h3>
# <blockquote>
# <b>Metaparameters</b> are configuration variables external to the model and whose values cannot be estimated from the data. They are usually set manually or optimized through tuning techniques.
# </blockquote>
#
# <hr>
#
# <h3>🎯 Examples of Common Metaparameters:</h3>
# <table>
#   <thead>
#     <tr>
#       <th>Metaparameter</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr><td><code>learning rate</code></td><td>Controls the size of the update step during training.</td></tr>
#     <tr><td><code>batch size</code></td><td>Number of samples processed before model update.</td></tr>
#     <tr><td><code>num_epochs</code></td><td>Number of complete passes through the training data.</td></tr>
#     <tr><td><code>hidden layers</code></td><td>Structure of the neural network.</td></tr>
#     <tr><td><code>activation function</code></td><td>Function that introduces non-linearity (e.g., ReLU, Sigmoid).</td></tr>
#     <tr><td><code>optimizer</code></td><td>Method used to minimize the loss (e.g., Adam, SGD).</td></tr>
#     <tr><td><code>dropout rate</code></td><td>Portion of nodes randomly dropped during training.</td></tr>
#     <tr><td><code>L2 regularization (λ)</code></td><td>Controls penalty on large weights to reduce overfitting.</td></tr>
#   </tbody>
# </table>
#
# <hr>
#
# <h3>🧠 Metaparameter vs Parameter:</h3>
# <table>
#   <thead>
#     <tr><th>Feature</th><th>Parameters</th><th>Metaparameters (Hyperparameters)</th></tr>
#   </thead>
#   <tbody>
#     <tr><td>Learned during training</td><td>✅ Yes</td><td>❌ No</td></tr>
#     <tr><td>Examples</td><td>Weights, Biases</td><td>Learning rate, Epochs, Batch size</td></tr>
#     <tr><td>Set manually or tuned?</td><td>❌ No</td><td>✅ Yes</td></tr>
#   </tbody>
# </table>
#
# <hr>
#
# <h3>🛠️ How to Choose Metaparameters?</h3>
# <ul>
#   <li>Grid Search</li>
#   <li>Random Search</li>
#   <li>Bayesian Optimization</li>
#   <li>Cross-Validation</li>
#   <li>AutoML Tools</li>
# </ul>
#
# <hr>
#
# <h3>🇧🇩 বাংলায় সংক্ষেপে:</h3>
# <p><b>Metaparameter (মেটাপ্যারামিটার)</b> হল এমন কিছু মান যা মডেল ট্রেনিং শুরু করার আগে ঠিক করা হয়। এগুলো ডেটা থেকে শেখা হয় না।</p>
# <ul>
#   <li>যেমন: <code>learning rate</code>, <code>epoch</code> সংখ্যা, <code>batch size</code></li>
#   <li>এই মানগুলো ঠিকভাবে নির্ধারণ করলে মডেলের পারফরম্যান্স অনেক ভালো হতে পারে।</li>
# </ul>
